# %% [markdown]
# # Чтение и запись данных форматов .xlsx, .csv, .json. Работа с SQL, MongoDB.
#
# ### Цель работы
# Продемонстрировать навыки работы с файлами - чтение, запись, подключение к БД, написание SQL-запросов.
#
#
# ### Результат
# Файл формата .ipynb, показывающий уровень владения инструментами.

# %% [markdown]
# ### Начало работы

# %% [markdown]
# Используя сервис WeatherAPI, получим прогноз погоды в Лондоне на следующие 2 дня. Ответ преобразуем к типу JSON.

# %%
import urllib.request as req
import json
import pandas as pd

days = 2
API_KEY = '051fd0dfead0431abf4103206230406'
url = f'http://api.weatherapi.com/v1/forecast.json?key={API_KEY}&q=London&days={days}'

with req.urlopen(url) as session:
    response = session.read().decode()
    data_1 = json.loads(response)   # для более комфортного чтения файла 
    
data_1
# Out:
# {'location': {'name': 'London',
#   'region': 'City of London, Greater London',
#   'country': 'United Kingdom',
#   'lat': 51.52,
#   'lon': -0.11,
#   'tz_id': 'Europe/London',
#   'localtime_epoch': 1695823539,
#   'localtime': '2023-09-27 15:05'},
#  'current': {'last_updated_epoch': 1695823200,
#   'last_updated': '2023-09-27 15:00',
#   'temp_c': 21.0,
#   'temp_f': 69.8,
#   'is_day': 1,
#   'condition': {'text': 'Partly cloudy',
#    'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#    'code': 1003},
#   'wind_mph': 12.5,
#   'wind_kph': 20.2,
#   'wind_degree': 170,
#   'wind_dir': 'S',
#   'pressure_mb': 1011.0,
#   'pressure_in': 29.85,
#   'precip_mm': 0.0,
#   'precip_in': 0.0,
#   'humidity': 69,
#   'cloud': 75,
#   'feelslike_c': 21.0,
#   'feelslike_f': 69.8,
#   'vis_km': 10.0,
#   'vis_miles': 6.0,
#   'uv': 5.0,
#   'gust_mph': 17.2,
#   'gust_kph': 27.7},
#  'forecast': {'forecastday': [{'date': '2023-09-27',
#     'date_epoch': 1695772800,
#     'day': {'maxtemp_c': 20.9,
#      'maxtemp_f': 69.6,
#      'mintemp_c': 15.1,
#      'mintemp_f': 59.1,
#      'avgtemp_c': 17.6,
#      'avgtemp_f': 63.6,
#      'maxwind_mph': 17.0,
#      'maxwind_kph': 27.4,
#      'totalprecip_mm': 0.04,
#      'totalprecip_in': 0.0,
#      'totalsnow_cm': 0.0,
#      'avgvis_km': 10.0,
#      'avgvis_miles': 6.0,
#      'avghumidity': 77.0,
#      'daily_will_it_rain': 0,
#      'daily_chance_of_rain': 0,
#      'daily_will_it_snow': 0,
#      'daily_chance_of_snow': 0,
#      'condition': {'text': 'Partly cloudy',
#       'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#       'code': 1003},
#      'uv': 5.0},
#     'astro': {'sunrise': '06:54 AM',
#      'sunset': '06:48 PM',
#      'moonrise': '06:27 PM',
#      'moonset': '03:39 AM',
#      'moon_phase': 'Waxing Gibbous',
#      'moon_illumination': '91',
#      'is_moon_up': 1,
#      'is_sun_up': 0},
#     'hour': [{'time_epoch': 1695769200,
#       'time': '2023-09-27 00:00',
#       'temp_c': 15.6,
#       'temp_f': 60.0,
#       'is_day': 0,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#        'code': 1003},
#       'wind_mph': 2.9,
#       'wind_kph': 4.7,
#       'wind_degree': 205,
#       'wind_dir': 'SSW',
#       'pressure_mb': 1018.0,
#       'pressure_in': 30.06,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 92,
#       'cloud': 43,
#       'feelslike_c': 15.6,
#       'feelslike_f': 60.0,
#       'windchill_c': 15.6,
#       'windchill_f': 60.0,
#       'heatindex_c': 15.6,
#       'heatindex_f': 60.0,
#       'dewpoint_c': 14.3,
#       'dewpoint_f': 57.7,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 4.5,
#       'gust_kph': 7.3,
#       'uv': 1.0},
#      {'time_epoch': 1695772800,
#       'time': '2023-09-27 01:00',
#       'temp_c': 15.3,
#       'temp_f': 59.5,
#       'is_day': 0,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#        'code': 1003},
#       'wind_mph': 3.4,
#       'wind_kph': 5.4,
#       'wind_degree': 191,
#       'wind_dir': 'SSW',
#       'pressure_mb': 1018.0,
#       'pressure_in': 30.06,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 93,
#       'cloud': 45,
#       'feelslike_c': 15.3,
#       'feelslike_f': 59.5,
#       'windchill_c': 15.3,
#       'windchill_f': 59.5,
#       'heatindex_c': 15.3,
#       'heatindex_f': 59.5,
#       'dewpoint_c': 14.1,
#       'dewpoint_f': 57.4,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 5.4,
#       'gust_kph': 8.7,
#       'uv': 1.0},
#      {'time_epoch': 1695776400,
#       'time': '2023-09-27 02:00',
#       'temp_c': 15.2,
#       'temp_f': 59.4,
#       'is_day': 0,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#        'code': 1003},
#       'wind_mph': 2.7,
#       'wind_kph': 4.3,
#       'wind_degree': 184,
#       'wind_dir': 'S',
#       'pressure_mb': 1018.0,
#       'pressure_in': 30.06,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 92,
#       'cloud': 41,
#       'feelslike_c': 15.2,
#       'feelslike_f': 59.4,
#       'windchill_c': 15.2,
#       'windchill_f': 59.4,
#       'heatindex_c': 15.2,
#       'heatindex_f': 59.4,
#       'dewpoint_c': 13.9,
#       'dewpoint_f': 56.9,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 4.3,
#       'gust_kph': 7.0,
#       'uv': 1.0},
#      {'time_epoch': 1695780000,
#       'time': '2023-09-27 03:00',
#       'temp_c': 15.2,
#       'temp_f': 59.4,
#       'is_day': 0,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#        'code': 1003},
#       'wind_mph': 3.1,
#       'wind_kph': 5.0,
#       'wind_degree': 159,
#       'wind_dir': 'SSE',
#       'pressure_mb': 1018.0,
#       'pressure_in': 30.05,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 90,
#       'cloud': 43,
#       'feelslike_c': 15.2,
#       'feelslike_f': 59.4,
#       'windchill_c': 15.2,
#       'windchill_f': 59.4,
#       'heatindex_c': 15.2,
#       'heatindex_f': 59.4,
#       'dewpoint_c': 13.6,
#       'dewpoint_f': 56.4,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 5.1,
#       'gust_kph': 8.2,
#       'uv': 1.0},
#      {'time_epoch': 1695783600,
#       'time': '2023-09-27 04:00',
#       'temp_c': 15.3,
#       'temp_f': 59.5,
#       'is_day': 0,
#       'condition': {'text': 'Overcast',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/122.png',
#        'code': 1009},
#       'wind_mph': 3.1,
#       'wind_kph': 5.0,
#       'wind_degree': 178,
#       'wind_dir': 'S',
#       'pressure_mb': 1018.0,
#       'pressure_in': 30.05,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 89,
#       'cloud': 91,
#       'feelslike_c': 15.3,
#       'feelslike_f': 59.5,
#       'windchill_c': 15.3,
#       'windchill_f': 59.5,
#       'heatindex_c': 15.3,
#       'heatindex_f': 59.5,
#       'dewpoint_c': 13.5,
#       'dewpoint_f': 56.2,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 5.1,
#       'gust_kph': 8.1,
#       'uv': 1.0},
#      {'time_epoch': 1695787200,
#       'time': '2023-09-27 05:00',
#       'temp_c': 15.1,
#       'temp_f': 59.1,
#       'is_day': 0,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#        'code': 1003},
#       'wind_mph': 3.4,
#       'wind_kph': 5.4,
#       'wind_degree': 154,
#       'wind_dir': 'SSE',
#       'pressure_mb': 1017.0,
#       'pressure_in': 30.04,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 90,
#       'cloud': 49,
#       'feelslike_c': 15.1,
#       'feelslike_f': 59.1,
#       'windchill_c': 15.1,
#       'windchill_f': 59.1,
#       'heatindex_c': 15.1,
#       'heatindex_f': 59.1,
#       'dewpoint_c': 13.5,
#       'dewpoint_f': 56.3,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 5.6,
#       'gust_kph': 9.0,
#       'uv': 1.0},
#      {'time_epoch': 1695790800,
#       'time': '2023-09-27 06:00',
#       'temp_c': 15.3,
#       'temp_f': 59.5,
#       'is_day': 0,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#        'code': 1003},
#       'wind_mph': 3.6,
#       'wind_kph': 5.8,
#       'wind_degree': 147,
#       'wind_dir': 'SSE',
#       'pressure_mb': 1017.0,
#       'pressure_in': 30.03,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 91,
#       'cloud': 61,
#       'feelslike_c': 15.3,
#       'feelslike_f': 59.5,
#       'windchill_c': 15.3,
#       'windchill_f': 59.5,
#       'heatindex_c': 15.3,
#       'heatindex_f': 59.5,
#       'dewpoint_c': 13.9,
#       'dewpoint_f': 57.0,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 5.8,
#       'gust_kph': 9.4,
#       'uv': 1.0},
#      {'time_epoch': 1695794400,
#       'time': '2023-09-27 07:00',
#       'temp_c': 15.7,
#       'temp_f': 60.2,
#       'is_day': 1,
#       'condition': {'text': 'Cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/119.png',
#        'code': 1006},
#       'wind_mph': 4.9,
#       'wind_kph': 7.9,
#       'wind_degree': 151,
#       'wind_dir': 'SSE',
#       'pressure_mb': 1017.0,
#       'pressure_in': 30.02,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 92,
#       'cloud': 65,
#       'feelslike_c': 15.7,
#       'feelslike_f': 60.2,
#       'windchill_c': 15.7,
#       'windchill_f': 60.2,
#       'heatindex_c': 15.7,
#       'heatindex_f': 60.2,
#       'dewpoint_c': 14.3,
#       'dewpoint_f': 57.8,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 7.8,
#       'gust_kph': 12.5,
#       'uv': 4.0},
#      {'time_epoch': 1695798000,
#       'time': '2023-09-27 08:00',
#       'temp_c': 16.9,
#       'temp_f': 62.5,
#       'is_day': 1,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#        'code': 1003},
#       'wind_mph': 7.2,
#       'wind_kph': 11.5,
#       'wind_degree': 148,
#       'wind_dir': 'SSE',
#       'pressure_mb': 1016.0,
#       'pressure_in': 30.01,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 86,
#       'cloud': 44,
#       'feelslike_c': 16.9,
#       'feelslike_f': 62.5,
#       'windchill_c': 16.9,
#       'windchill_f': 62.5,
#       'heatindex_c': 16.9,
#       'heatindex_f': 62.5,
#       'dewpoint_c': 14.7,
#       'dewpoint_f': 58.4,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 9.9,
#       'gust_kph': 16.0,
#       'uv': 5.0},
#      {'time_epoch': 1695801600,
#       'time': '2023-09-27 09:00',
#       'temp_c': 18.6,
#       'temp_f': 65.5,
#       'is_day': 1,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#        'code': 1003},
#       'wind_mph': 10.1,
#       'wind_kph': 16.2,
#       'wind_degree': 150,
#       'wind_dir': 'SSE',
#       'pressure_mb': 1016.0,
#       'pressure_in': 29.99,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 77,
#       'cloud': 36,
#       'feelslike_c': 18.6,
#       'feelslike_f': 65.6,
#       'windchill_c': 18.6,
#       'windchill_f': 65.6,
#       'heatindex_c': 18.6,
#       'heatindex_f': 65.6,
#       'dewpoint_c': 14.5,
#       'dewpoint_f': 58.1,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 12.7,
#       'gust_kph': 20.4,
#       'uv': 5.0},
#      {'time_epoch': 1695805200,
#       'time': '2023-09-27 10:00',
#       'temp_c': 19.1,
#       'temp_f': 66.4,
#       'is_day': 1,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#        'code': 1003},
#       'wind_mph': 10.7,
#       'wind_kph': 17.3,
#       'wind_degree': 146,
#       'wind_dir': 'SSE',
#       'pressure_mb': 1015.0,
#       'pressure_in': 29.97,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 72,
#       'cloud': 55,
#       'feelslike_c': 19.1,
#       'feelslike_f': 66.4,
#       'windchill_c': 19.1,
#       'windchill_f': 66.4,
#       'heatindex_c': 19.1,
#       'heatindex_f': 66.4,
#       'dewpoint_c': 14.1,
#       'dewpoint_f': 57.3,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 13.4,
#       'gust_kph': 21.5,
#       'uv': 5.0},
#      {'time_epoch': 1695808800,
#       'time': '2023-09-27 11:00',
#       'temp_c': 20.3,
#       'temp_f': 68.5,
#       'is_day': 1,
#       'condition': {'text': 'Cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/119.png',
#        'code': 1006},
#       'wind_mph': 12.3,
#       'wind_kph': 19.8,
#       'wind_degree': 153,
#       'wind_dir': 'SSE',
#       'pressure_mb': 1014.0,
#       'pressure_in': 29.94,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 67,
#       'cloud': 85,
#       'feelslike_c': 20.3,
#       'feelslike_f': 68.5,
#       'windchill_c': 20.3,
#       'windchill_f': 68.5,
#       'heatindex_c': 20.3,
#       'heatindex_f': 68.5,
#       'dewpoint_c': 13.9,
#       'dewpoint_f': 57.1,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 14.4,
#       'gust_kph': 23.1,
#       'uv': 5.0},
#      {'time_epoch': 1695812400,
#       'time': '2023-09-27 12:00',
#       'temp_c': 20.9,
#       'temp_f': 69.6,
#       'is_day': 1,
#       'condition': {'text': 'Cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/119.png',
#        'code': 1006},
#       'wind_mph': 10.7,
#       'wind_kph': 17.3,
#       'wind_degree': 172,
#       'wind_dir': 'S',
#       'pressure_mb': 1013.0,
#       'pressure_in': 29.92,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 66,
#       'cloud': 84,
#       'feelslike_c': 20.9,
#       'feelslike_f': 69.6,
#       'windchill_c': 20.9,
#       'windchill_f': 69.6,
#       'heatindex_c': 20.9,
#       'heatindex_f': 69.6,
#       'dewpoint_c': 14.4,
#       'dewpoint_f': 58.0,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 13.4,
#       'gust_kph': 21.5,
#       'uv': 5.0},
#      {'time_epoch': 1695816000,
#       'time': '2023-09-27 13:00',
#       'temp_c': 20.3,
#       'temp_f': 68.5,
#       'is_day': 1,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#        'code': 1003},
#       'wind_mph': 10.7,
#       'wind_kph': 17.3,
#       'wind_degree': 172,
#       'wind_dir': 'S',
#       'pressure_mb': 1012.0,
#       'pressure_in': 29.9,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 65,
#       'cloud': 49,
#       'feelslike_c': 20.3,
#       'feelslike_f': 68.5,
#       'windchill_c': 20.3,
#       'windchill_f': 68.5,
#       'heatindex_c': 20.3,
#       'heatindex_f': 68.5,
#       'dewpoint_c': 13.6,
#       'dewpoint_f': 56.4,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 14.7,
#       'gust_kph': 23.7,
#       'uv': 6.0},
#      {'time_epoch': 1695819600,
#       'time': '2023-09-27 14:00',
#       'temp_c': 20.3,
#       'temp_f': 68.6,
#       'is_day': 1,
#       'condition': {'text': 'Overcast',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/122.png',
#        'code': 1009},
#       'wind_mph': 11.4,
#       'wind_kph': 18.4,
#       'wind_degree': 177,
#       'wind_dir': 'S',
#       'pressure_mb': 1012.0,
#       'pressure_in': 29.88,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 59,
#       'cloud': 96,
#       'feelslike_c': 20.3,
#       'feelslike_f': 68.6,
#       'windchill_c': 20.3,
#       'windchill_f': 68.6,
#       'heatindex_c': 20.3,
#       'heatindex_f': 68.6,
#       'dewpoint_c': 12.1,
#       'dewpoint_f': 53.7,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 15.1,
#       'gust_kph': 24.3,
#       'uv': 5.0},
#      {'time_epoch': 1695823200,
#       'time': '2023-09-27 15:00',
#       'temp_c': 21.0,
#       'temp_f': 69.8,
#       'is_day': 1,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#        'code': 1003},
#       'wind_mph': 12.5,
#       'wind_kph': 20.2,
#       'wind_degree': 170,
#       'wind_dir': 'S',
#       'pressure_mb': 1011.0,
#       'pressure_in': 29.85,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 69,
#       'cloud': 75,
#       'feelslike_c': 19.9,
#       'feelslike_f': 67.8,
#       'windchill_c': 19.9,
#       'windchill_f': 67.8,
#       'heatindex_c': 19.9,
#       'heatindex_f': 67.8,
#       'dewpoint_c': 11.6,
#       'dewpoint_f': 52.9,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 17.2,
#       'gust_kph': 27.7,
#       'uv': 5.0},
#      {'time_epoch': 1695826800,
#       'time': '2023-09-27 16:00',
#       'temp_c': 19.3,
#       'temp_f': 66.7,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 12.3,
#       'wind_kph': 19.8,
#       'wind_degree': 171,
#       'wind_dir': 'S',
#       'pressure_mb': 1009.0,
#       'pressure_in': 29.8,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 60,
#       'cloud': 16,
#       'feelslike_c': 19.3,
#       'feelslike_f': 66.7,
#       'windchill_c': 19.3,
#       'windchill_f': 66.7,
#       'heatindex_c': 19.3,
#       'heatindex_f': 66.7,
#       'dewpoint_c': 11.4,
#       'dewpoint_f': 52.6,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 18.1,
#       'gust_kph': 29.2,
#       'uv': 5.0},
#      {'time_epoch': 1695830400,
#       'time': '2023-09-27 17:00',
#       'temp_c': 19.2,
#       'temp_f': 66.6,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 14.5,
#       'wind_kph': 23.4,
#       'wind_degree': 183,
#       'wind_dir': 'S',
#       'pressure_mb': 1009.0,
#       'pressure_in': 29.8,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 64,
#       'cloud': 16,
#       'feelslike_c': 19.2,
#       'feelslike_f': 66.6,
#       'windchill_c': 19.2,
#       'windchill_f': 66.6,
#       'heatindex_c': 19.2,
#       'heatindex_f': 66.6,
#       'dewpoint_c': 12.1,
#       'dewpoint_f': 53.9,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 21.2,
#       'gust_kph': 34.1,
#       'uv': 5.0},
#      {'time_epoch': 1695834000,
#       'time': '2023-09-27 18:00',
#       'temp_c': 18.9,
#       'temp_f': 66.0,
#       'is_day': 1,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#        'code': 1003},
#       'wind_mph': 15.2,
#       'wind_kph': 24.5,
#       'wind_degree': 192,
#       'wind_dir': 'SSW',
#       'pressure_mb': 1009.0,
#       'pressure_in': 29.8,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 70,
#       'cloud': 55,
#       'feelslike_c': 18.9,
#       'feelslike_f': 66.0,
#       'windchill_c': 18.9,
#       'windchill_f': 66.0,
#       'heatindex_c': 18.9,
#       'heatindex_f': 66.0,
#       'dewpoint_c': 13.2,
#       'dewpoint_f': 55.8,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 23.3,
#       'gust_kph': 37.5,
#       'uv': 5.0},
#      {'time_epoch': 1695837600,
#       'time': '2023-09-27 19:00',
#       'temp_c': 18.7,
#       'temp_f': 65.7,
#       'is_day': 0,
#       'condition': {'text': 'Patchy rain possible',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/176.png',
#        'code': 1063},
#       'wind_mph': 17.0,
#       'wind_kph': 27.4,
#       'wind_degree': 205,
#       'wind_dir': 'SSW',
#       'pressure_mb': 1009.0,
#       'pressure_in': 29.8,
#       'precip_mm': 0.03,
#       'precip_in': 0.0,
#       'humidity': 75,
#       'cloud': 93,
#       'feelslike_c': 18.7,
#       'feelslike_f': 65.7,
#       'windchill_c': 18.7,
#       'windchill_f': 65.7,
#       'heatindex_c': 18.7,
#       'heatindex_f': 65.7,
#       'dewpoint_c': 14.2,
#       'dewpoint_f': 57.6,
#       'will_it_rain': 1,
#       'chance_of_rain': 80,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 25.5,
#       'gust_kph': 41.0,
#       'uv': 1.0},
#      {'time_epoch': 1695841200,
#       'time': '2023-09-27 20:00',
#       'temp_c': 18.0,
#       'temp_f': 64.3,
#       'is_day': 0,
#       'condition': {'text': 'Clear',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 16.3,
#       'wind_kph': 26.3,
#       'wind_degree': 219,
#       'wind_dir': 'SW',
#       'pressure_mb': 1009.0,
#       'pressure_in': 29.81,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 75,
#       'cloud': 12,
#       'feelslike_c': 18.0,
#       'feelslike_f': 64.3,
#       'windchill_c': 18.0,
#       'windchill_f': 64.3,
#       'heatindex_c': 18.0,
#       'heatindex_f': 64.3,
#       'dewpoint_c': 13.4,
#       'dewpoint_f': 56.2,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 22.8,
#       'gust_kph': 36.7,
#       'uv': 1.0},
#      {'time_epoch': 1695844800,
#       'time': '2023-09-27 21:00',
#       'temp_c': 16.5,
#       'temp_f': 61.7,
#       'is_day': 0,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#        'code': 1003},
#       'wind_mph': 15.9,
#       'wind_kph': 25.6,
#       'wind_degree': 221,
#       'wind_dir': 'SW',
#       'pressure_mb': 1010.0,
#       'pressure_in': 29.82,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 75,
#       'cloud': 59,
#       'feelslike_c': 16.5,
#       'feelslike_f': 61.7,
#       'windchill_c': 16.5,
#       'windchill_f': 61.7,
#       'heatindex_c': 16.5,
#       'heatindex_f': 61.7,
#       'dewpoint_c': 12.1,
#       'dewpoint_f': 53.7,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 22.6,
#       'gust_kph': 36.4,
#       'uv': 1.0},
#      {'time_epoch': 1695848400,
#       'time': '2023-09-27 22:00',
#       'temp_c': 16.0,
#       'temp_f': 60.8,
#       'is_day': 0,
#       'condition': {'text': 'Cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/119.png',
#        'code': 1006},
#       'wind_mph': 15.4,
#       'wind_kph': 24.8,
#       'wind_degree': 223,
#       'wind_dir': 'SW',
#       'pressure_mb': 1011.0,
#       'pressure_in': 29.84,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 76,
#       'cloud': 87,
#       'feelslike_c': 16.0,
#       'feelslike_f': 60.8,
#       'windchill_c': 16.0,
#       'windchill_f': 60.8,
#       'heatindex_c': 16.0,
#       'heatindex_f': 60.8,
#       'dewpoint_c': 11.8,
#       'dewpoint_f': 53.2,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 22.0,
#       'gust_kph': 35.4,
#       'uv': 1.0},
#      {'time_epoch': 1695852000,
#       'time': '2023-09-27 23:00',
#       'temp_c': 15.8,
#       'temp_f': 60.4,
#       'is_day': 0,
#       'condition': {'text': 'Patchy rain possible',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/176.png',
#        'code': 1063},
#       'wind_mph': 15.0,
#       'wind_kph': 24.1,
#       'wind_degree': 229,
#       'wind_dir': 'SW',
#       'pressure_mb': 1011.0,
#       'pressure_in': 29.85,
#       'precip_mm': 0.01,
#       'precip_in': 0.0,
#       'humidity': 77,
#       'cloud': 100,
#       'feelslike_c': 15.8,
#       'feelslike_f': 60.4,
#       'windchill_c': 15.8,
#       'windchill_f': 60.4,
#       'heatindex_c': 15.8,
#       'heatindex_f': 60.4,
#       'dewpoint_c': 11.7,
#       'dewpoint_f': 53.0,
#       'will_it_rain': 1,
#       'chance_of_rain': 83,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 21.3,
#       'gust_kph': 34.2,
#       'uv': 1.0}]},
#    {'date': '2023-09-28',
#     'date_epoch': 1695859200,
#     'day': {'maxtemp_c': 19.7,
#      'maxtemp_f': 67.5,
#      'mintemp_c': 14.6,
#      'mintemp_f': 58.3,
#      'avgtemp_c': 16.7,
#      'avgtemp_f': 62.1,
#      'maxwind_mph': 15.9,
#      'maxwind_kph': 25.6,
#      'totalprecip_mm': 0.16,
#      'totalprecip_in': 0.01,
#      'totalsnow_cm': 0.0,
#      'avgvis_km': 10.0,
#      'avgvis_miles': 6.0,
#      'avghumidity': 65.0,
#      'daily_will_it_rain': 1,
#      'daily_chance_of_rain': 86,
#      'daily_will_it_snow': 0,
#      'daily_chance_of_snow': 0,
#      'condition': {'text': 'Patchy rain possible',
#       'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png',
#       'code': 1063},
#      'uv': 4.0},
#     'astro': {'sunrise': '06:56 AM',
#      'sunset': '06:46 PM',
#      'moonrise': '06:41 PM',
#      'moonset': '05:11 AM',
#      'moon_phase': 'Waxing Gibbous',
#      'moon_illumination': '97',
#      'is_moon_up': 1,
#      'is_sun_up': 0},
#     'hour': [{'time_epoch': 1695855600,
#       'time': '2023-09-28 00:00',
#       'temp_c': 16.2,
#       'temp_f': 61.2,
#       'is_day': 0,
#       'condition': {'text': 'Cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/119.png',
#        'code': 1006},
#       'wind_mph': 15.9,
#       'wind_kph': 25.6,
#       'wind_degree': 236,
#       'wind_dir': 'WSW',
#       'pressure_mb': 1011.0,
#       'pressure_in': 29.86,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 71,
#       'cloud': 73,
#       'feelslike_c': 16.2,
#       'feelslike_f': 61.2,
#       'windchill_c': 16.2,
#       'windchill_f': 61.2,
#       'heatindex_c': 16.2,
#       'heatindex_f': 61.2,
#       'dewpoint_c': 11.0,
#       'dewpoint_f': 51.7,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 21.7,
#       'gust_kph': 35.0,
#       'uv': 1.0},
#      {'time_epoch': 1695859200,
#       'time': '2023-09-28 01:00',
#       'temp_c': 15.6,
#       'temp_f': 60.1,
#       'is_day': 0,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#        'code': 1003},
#       'wind_mph': 14.3,
#       'wind_kph': 23.0,
#       'wind_degree': 237,
#       'wind_dir': 'WSW',
#       'pressure_mb': 1012.0,
#       'pressure_in': 29.88,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 74,
#       'cloud': 55,
#       'feelslike_c': 15.6,
#       'feelslike_f': 60.1,
#       'windchill_c': 15.6,
#       'windchill_f': 60.1,
#       'heatindex_c': 15.6,
#       'heatindex_f': 60.1,
#       'dewpoint_c': 11.1,
#       'dewpoint_f': 51.9,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 19.9,
#       'gust_kph': 32.0,
#       'uv': 1.0},
#      {'time_epoch': 1695862800,
#       'time': '2023-09-28 02:00',
#       'temp_c': 14.8,
#       'temp_f': 58.6,
#       'is_day': 0,
#       'condition': {'text': 'Overcast',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/122.png',
#        'code': 1009},
#       'wind_mph': 13.0,
#       'wind_kph': 20.9,
#       'wind_degree': 239,
#       'wind_dir': 'WSW',
#       'pressure_mb': 1012.0,
#       'pressure_in': 29.89,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 77,
#       'cloud': 91,
#       'feelslike_c': 13.4,
#       'feelslike_f': 56.1,
#       'windchill_c': 13.4,
#       'windchill_f': 56.1,
#       'heatindex_c': 14.8,
#       'heatindex_f': 58.6,
#       'dewpoint_c': 10.8,
#       'dewpoint_f': 51.5,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 18.6,
#       'gust_kph': 29.9,
#       'uv': 1.0},
#      {'time_epoch': 1695866400,
#       'time': '2023-09-28 03:00',
#       'temp_c': 15.1,
#       'temp_f': 59.1,
#       'is_day': 0,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#        'code': 1003},
#       'wind_mph': 11.6,
#       'wind_kph': 18.7,
#       'wind_degree': 240,
#       'wind_dir': 'WSW',
#       'pressure_mb': 1013.0,
#       'pressure_in': 29.91,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 71,
#       'cloud': 45,
#       'feelslike_c': 15.1,
#       'feelslike_f': 59.1,
#       'windchill_c': 15.1,
#       'windchill_f': 59.1,
#       'heatindex_c': 15.1,
#       'heatindex_f': 59.1,
#       'dewpoint_c': 9.8,
#       'dewpoint_f': 49.7,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 17.0,
#       'gust_kph': 27.3,
#       'uv': 1.0},
#      {'time_epoch': 1695870000,
#       'time': '2023-09-28 04:00',
#       'temp_c': 14.9,
#       'temp_f': 58.8,
#       'is_day': 0,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#        'code': 1003},
#       'wind_mph': 10.5,
#       'wind_kph': 16.9,
#       'wind_degree': 234,
#       'wind_dir': 'SW',
#       'pressure_mb': 1013.0,
#       'pressure_in': 29.92,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 69,
#       'cloud': 35,
#       'feelslike_c': 13.8,
#       'feelslike_f': 56.9,
#       'windchill_c': 13.8,
#       'windchill_f': 56.9,
#       'heatindex_c': 14.9,
#       'heatindex_f': 58.9,
#       'dewpoint_c': 9.2,
#       'dewpoint_f': 48.6,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 16.0,
#       'gust_kph': 25.8,
#       'uv': 1.0},
#      {'time_epoch': 1695873600,
#       'time': '2023-09-28 05:00',
#       'temp_c': 14.9,
#       'temp_f': 58.8,
#       'is_day': 0,
#       'condition': {'text': 'Clear',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 10.3,
#       'wind_kph': 16.6,
#       'wind_degree': 233,
#       'wind_dir': 'SW',
#       'pressure_mb': 1014.0,
#       'pressure_in': 29.95,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 68,
#       'cloud': 11,
#       'feelslike_c': 13.8,
#       'feelslike_f': 56.9,
#       'windchill_c': 13.8,
#       'windchill_f': 56.9,
#       'heatindex_c': 14.9,
#       'heatindex_f': 58.8,
#       'dewpoint_c': 9.2,
#       'dewpoint_f': 48.5,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 15.8,
#       'gust_kph': 25.4,
#       'uv': 1.0},
#      {'time_epoch': 1695877200,
#       'time': '2023-09-28 06:00',
#       'temp_c': 14.6,
#       'temp_f': 58.3,
#       'is_day': 0,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#        'code': 1003},
#       'wind_mph': 9.2,
#       'wind_kph': 14.8,
#       'wind_degree': 230,
#       'wind_dir': 'SW',
#       'pressure_mb': 1015.0,
#       'pressure_in': 29.96,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 70,
#       'cloud': 35,
#       'feelslike_c': 13.6,
#       'feelslike_f': 56.5,
#       'windchill_c': 13.6,
#       'windchill_f': 56.5,
#       'heatindex_c': 14.6,
#       'heatindex_f': 58.3,
#       'dewpoint_c': 9.1,
#       'dewpoint_f': 48.4,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 14.1,
#       'gust_kph': 22.6,
#       'uv': 1.0},
#      {'time_epoch': 1695880800,
#       'time': '2023-09-28 07:00',
#       'temp_c': 14.7,
#       'temp_f': 58.4,
#       'is_day': 1,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#        'code': 1003},
#       'wind_mph': 9.2,
#       'wind_kph': 14.8,
#       'wind_degree': 233,
#       'wind_dir': 'SW',
#       'pressure_mb': 1015.0,
#       'pressure_in': 29.98,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 71,
#       'cloud': 45,
#       'feelslike_c': 13.7,
#       'feelslike_f': 56.7,
#       'windchill_c': 13.7,
#       'windchill_f': 56.7,
#       'heatindex_c': 14.7,
#       'heatindex_f': 58.4,
#       'dewpoint_c': 9.4,
#       'dewpoint_f': 49.0,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 13.1,
#       'gust_kph': 21.0,
#       'uv': 4.0},
#      {'time_epoch': 1695884400,
#       'time': '2023-09-28 08:00',
#       'temp_c': 15.1,
#       'temp_f': 59.1,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 8.7,
#       'wind_kph': 14.0,
#       'wind_degree': 231,
#       'wind_dir': 'SW',
#       'pressure_mb': 1016.0,
#       'pressure_in': 29.99,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 72,
#       'cloud': 15,
#       'feelslike_c': 15.1,
#       'feelslike_f': 59.1,
#       'windchill_c': 15.1,
#       'windchill_f': 59.1,
#       'heatindex_c': 15.1,
#       'heatindex_f': 59.1,
#       'dewpoint_c': 10.0,
#       'dewpoint_f': 50.0,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 11.4,
#       'gust_kph': 18.3,
#       'uv': 5.0},
#      {'time_epoch': 1695888000,
#       'time': '2023-09-28 09:00',
#       'temp_c': 15.6,
#       'temp_f': 60.0,
#       'is_day': 1,
#       'condition': {'text': 'Cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/119.png',
#        'code': 1006},
#       'wind_mph': 9.8,
#       'wind_kph': 15.8,
#       'wind_degree': 230,
#       'wind_dir': 'SW',
#       'pressure_mb': 1016.0,
#       'pressure_in': 30.0,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 69,
#       'cloud': 69,
#       'feelslike_c': 15.6,
#       'feelslike_f': 60.0,
#       'windchill_c': 15.6,
#       'windchill_f': 60.0,
#       'heatindex_c': 15.6,
#       'heatindex_f': 60.0,
#       'dewpoint_c': 9.9,
#       'dewpoint_f': 49.8,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 12.5,
#       'gust_kph': 20.2,
#       'uv': 4.0},
#      {'time_epoch': 1695891600,
#       'time': '2023-09-28 10:00',
#       'temp_c': 16.5,
#       'temp_f': 61.6,
#       'is_day': 1,
#       'condition': {'text': 'Cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/119.png',
#        'code': 1006},
#       'wind_mph': 9.6,
#       'wind_kph': 15.5,
#       'wind_degree': 221,
#       'wind_dir': 'SW',
#       'pressure_mb': 1016.0,
#       'pressure_in': 29.99,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 62,
#       'cloud': 64,
#       'feelslike_c': 16.5,
#       'feelslike_f': 61.6,
#       'windchill_c': 16.5,
#       'windchill_f': 61.6,
#       'heatindex_c': 16.5,
#       'heatindex_f': 61.6,
#       'dewpoint_c': 9.2,
#       'dewpoint_f': 48.5,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 11.8,
#       'gust_kph': 19.0,
#       'uv': 4.0},
#      {'time_epoch': 1695895200,
#       'time': '2023-09-28 11:00',
#       'temp_c': 18.0,
#       'temp_f': 64.3,
#       'is_day': 1,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#        'code': 1003},
#       'wind_mph': 10.5,
#       'wind_kph': 16.9,
#       'wind_degree': 223,
#       'wind_dir': 'SW',
#       'pressure_mb': 1016.0,
#       'pressure_in': 30.0,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 57,
#       'cloud': 57,
#       'feelslike_c': 18.0,
#       'feelslike_f': 64.3,
#       'windchill_c': 18.0,
#       'windchill_f': 64.3,
#       'heatindex_c': 18.0,
#       'heatindex_f': 64.3,
#       'dewpoint_c': 9.3,
#       'dewpoint_f': 48.7,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 12.1,
#       'gust_kph': 19.5,
#       'uv': 5.0},
#      {'time_epoch': 1695898800,
#       'time': '2023-09-28 12:00',
#       'temp_c': 19.1,
#       'temp_f': 66.3,
#       'is_day': 1,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#        'code': 1003},
#       'wind_mph': 9.8,
#       'wind_kph': 15.8,
#       'wind_degree': 219,
#       'wind_dir': 'SW',
#       'pressure_mb': 1016.0,
#       'pressure_in': 29.99,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 52,
#       'cloud': 60,
#       'feelslike_c': 19.1,
#       'feelslike_f': 66.3,
#       'windchill_c': 19.1,
#       'windchill_f': 66.3,
#       'heatindex_c': 19.1,
#       'heatindex_f': 66.3,
#       'dewpoint_c': 8.9,
#       'dewpoint_f': 48.1,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 11.3,
#       'gust_kph': 18.2,
#       'uv': 5.0},
#      {'time_epoch': 1695902400,
#       'time': '2023-09-28 13:00',
#       'temp_c': 19.7,
#       'temp_f': 67.5,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 11.6,
#       'wind_kph': 18.7,
#       'wind_degree': 215,
#       'wind_dir': 'SW',
#       'pressure_mb': 1015.0,
#       'pressure_in': 29.98,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 48,
#       'cloud': 19,
#       'feelslike_c': 19.7,
#       'feelslike_f': 67.5,
#       'windchill_c': 19.7,
#       'windchill_f': 67.5,
#       'heatindex_c': 19.7,
#       'heatindex_f': 67.5,
#       'dewpoint_c': 8.4,
#       'dewpoint_f': 47.1,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 13.4,
#       'gust_kph': 21.5,
#       'uv': 5.0},
#      {'time_epoch': 1695906000,
#       'time': '2023-09-28 14:00',
#       'temp_c': 19.7,
#       'temp_f': 67.4,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 12.1,
#       'wind_kph': 19.4,
#       'wind_degree': 213,
#       'wind_dir': 'SSW',
#       'pressure_mb': 1015.0,
#       'pressure_in': 29.97,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 49,
#       'cloud': 16,
#       'feelslike_c': 19.7,
#       'feelslike_f': 67.4,
#       'windchill_c': 19.7,
#       'windchill_f': 67.4,
#       'heatindex_c': 19.7,
#       'heatindex_f': 67.4,
#       'dewpoint_c': 8.6,
#       'dewpoint_f': 47.5,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 13.9,
#       'gust_kph': 22.4,
#       'uv': 5.0},
#      {'time_epoch': 1695909600,
#       'time': '2023-09-28 15:00',
#       'temp_c': 19.3,
#       'temp_f': 66.7,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 12.3,
#       'wind_kph': 19.8,
#       'wind_degree': 208,
#       'wind_dir': 'SSW',
#       'pressure_mb': 1014.0,
#       'pressure_in': 29.95,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 51,
#       'cloud': 16,
#       'feelslike_c': 19.3,
#       'feelslike_f': 66.7,
#       'windchill_c': 19.3,
#       'windchill_f': 66.7,
#       'heatindex_c': 19.3,
#       'heatindex_f': 66.7,
#       'dewpoint_c': 9.0,
#       'dewpoint_f': 48.2,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 14.8,
#       'gust_kph': 23.8,
#       'uv': 5.0},
#      {'time_epoch': 1695913200,
#       'time': '2023-09-28 16:00',
#       'temp_c': 18.7,
#       'temp_f': 65.6,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 11.6,
#       'wind_kph': 18.7,
#       'wind_degree': 207,
#       'wind_dir': 'SSW',
#       'pressure_mb': 1015.0,
#       'pressure_in': 29.96,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 55,
#       'cloud': 18,
#       'feelslike_c': 18.7,
#       'feelslike_f': 65.6,
#       'windchill_c': 18.7,
#       'windchill_f': 65.6,
#       'heatindex_c': 18.7,
#       'heatindex_f': 65.6,
#       'dewpoint_c': 9.6,
#       'dewpoint_f': 49.3,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 14.4,
#       'gust_kph': 23.2,
#       'uv': 5.0},
#      {'time_epoch': 1695916800,
#       'time': '2023-09-28 17:00',
#       'temp_c': 17.4,
#       'temp_f': 63.3,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 10.3,
#       'wind_kph': 16.6,
#       'wind_degree': 198,
#       'wind_dir': 'SSW',
#       'pressure_mb': 1014.0,
#       'pressure_in': 29.95,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 62,
#       'cloud': 5,
#       'feelslike_c': 17.4,
#       'feelslike_f': 63.3,
#       'windchill_c': 17.4,
#       'windchill_f': 63.3,
#       'heatindex_c': 17.4,
#       'heatindex_f': 63.3,
#       'dewpoint_c': 10.0,
#       'dewpoint_f': 49.9,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 13.7,
#       'gust_kph': 22.1,
#       'uv': 5.0},
#      {'time_epoch': 1695920400,
#       'time': '2023-09-28 18:00',
#       'temp_c': 16.5,
#       'temp_f': 61.8,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 8.7,
#       'wind_kph': 14.0,
#       'wind_degree': 193,
#       'wind_dir': 'SSW',
#       'pressure_mb': 1014.0,
#       'pressure_in': 29.96,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 68,
#       'cloud': 23,
#       'feelslike_c': 16.5,
#       'feelslike_f': 61.8,
#       'windchill_c': 16.5,
#       'windchill_f': 61.8,
#       'heatindex_c': 16.5,
#       'heatindex_f': 61.8,
#       'dewpoint_c': 10.6,
#       'dewpoint_f': 51.1,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 12.2,
#       'gust_kph': 19.7,
#       'uv': 5.0},
#      {'time_epoch': 1695924000,
#       'time': '2023-09-28 19:00',
#       'temp_c': 16.2,
#       'temp_f': 61.1,
#       'is_day': 0,
#       'condition': {'text': 'Overcast',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/122.png',
#        'code': 1009},
#       'wind_mph': 8.1,
#       'wind_kph': 13.0,
#       'wind_degree': 175,
#       'wind_dir': 'S',
#       'pressure_mb': 1014.0,
#       'pressure_in': 29.94,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 71,
#       'cloud': 97,
#       'feelslike_c': 16.2,
#       'feelslike_f': 61.1,
#       'windchill_c': 16.2,
#       'windchill_f': 61.1,
#       'heatindex_c': 16.2,
#       'heatindex_f': 61.1,
#       'dewpoint_c': 10.9,
#       'dewpoint_f': 51.6,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 11.6,
#       'gust_kph': 18.7,
#       'uv': 1.0},
#      {'time_epoch': 1695927600,
#       'time': '2023-09-28 20:00',
#       'temp_c': 16.4,
#       'temp_f': 61.6,
#       'is_day': 0,
#       'condition': {'text': 'Overcast',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/122.png',
#        'code': 1009},
#       'wind_mph': 9.6,
#       'wind_kph': 15.5,
#       'wind_degree': 166,
#       'wind_dir': 'SSE',
#       'pressure_mb': 1013.0,
#       'pressure_in': 29.92,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 70,
#       'cloud': 93,
#       'feelslike_c': 16.4,
#       'feelslike_f': 61.6,
#       'windchill_c': 16.4,
#       'windchill_f': 61.6,
#       'heatindex_c': 16.4,
#       'heatindex_f': 61.6,
#       'dewpoint_c': 10.9,
#       'dewpoint_f': 51.6,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 13.7,
#       'gust_kph': 22.1,
#       'uv': 1.0},
#      {'time_epoch': 1695931200,
#       'time': '2023-09-28 21:00',
#       'temp_c': 16.8,
#       'temp_f': 62.2,
#       'is_day': 0,
#       'condition': {'text': 'Patchy rain possible',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/176.png',
#        'code': 1063},
#       'wind_mph': 12.1,
#       'wind_kph': 19.4,
#       'wind_degree': 170,
#       'wind_dir': 'S',
#       'pressure_mb': 1013.0,
#       'pressure_in': 29.91,
#       'precip_mm': 0.06,
#       'precip_in': 0.0,
#       'humidity': 66,
#       'cloud': 100,
#       'feelslike_c': 16.8,
#       'feelslike_f': 62.2,
#       'windchill_c': 16.8,
#       'windchill_f': 62.2,
#       'heatindex_c': 16.8,
#       'heatindex_f': 62.2,
#       'dewpoint_c': 10.4,
#       'dewpoint_f': 50.7,
#       'will_it_rain': 1,
#       'chance_of_rain': 83,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 18.2,
#       'gust_kph': 29.3,
#       'uv': 1.0},
#      {'time_epoch': 1695934800,
#       'time': '2023-09-28 22:00',
#       'temp_c': 17.7,
#       'temp_f': 63.8,
#       'is_day': 0,
#       'condition': {'text': 'Patchy rain possible',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/176.png',
#        'code': 1063},
#       'wind_mph': 12.5,
#       'wind_kph': 20.2,
#       'wind_degree': 186,
#       'wind_dir': 'S',
#       'pressure_mb': 1012.0,
#       'pressure_in': 29.89,
#       'precip_mm': 0.1,
#       'precip_in': 0.0,
#       'humidity': 71,
#       'cloud': 100,
#       'feelslike_c': 17.7,
#       'feelslike_f': 63.8,
#       'windchill_c': 17.7,
#       'windchill_f': 63.8,
#       'heatindex_c': 17.7,
#       'heatindex_f': 63.8,
#       'dewpoint_c': 12.3,
#       'dewpoint_f': 54.1,
#       'will_it_rain': 1,
#       'chance_of_rain': 86,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 19.3,
#       'gust_kph': 31.0,
#       'uv': 1.0},
#      {'time_epoch': 1695938400,
#       'time': '2023-09-28 23:00',
#       'temp_c': 18.3,
#       'temp_f': 65.0,
#       'is_day': 0,
#       'condition': {'text': 'Overcast',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/122.png',
#        'code': 1009},
#       'wind_mph': 13.0,
#       'wind_kph': 20.9,
#       'wind_degree': 197,
#       'wind_dir': 'SSW',
#       'pressure_mb': 1012.0,
#       'pressure_in': 29.88,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 77,
#       'cloud': 91,
#       'feelslike_c': 18.3,
#       'feelslike_f': 65.0,
#       'windchill_c': 18.3,
#       'windchill_f': 65.0,
#       'heatindex_c': 18.3,
#       'heatindex_f': 65.0,
#       'dewpoint_c': 14.3,
#       'dewpoint_f': 57.8,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 19.7,
#       'gust_kph': 31.7,
#       'uv': 1.0}]}]}}

# %% [markdown]
# Сохраним данные погоды, полученные в предыдущей задаче, в файл `weather.json`. При сохранении используем четыре пробела для форматирования.

# %%
with open ('file_2.json', 'w') as file_2:
    json.dump(data_1, file_2, indent=4)

# %% [markdown]
# Из содержимого файла `weather.json` получим **почасовой** прогноз погоды, загрузим его в DataFrame и выведем первые пять строк DataFrame на экран.

# %%
with open ('file_2.json', 'r') as file_2:
    json.load(file_2)

d = []

for i_day in range(days):
    d_outer = data_1['forecast']['forecastday'][i_day]
    d = d + d_outer['hour']

df_3 = pd.DataFrame(d)
df_3.head()
# Out:
#    time_epoch              time  temp_c  temp_f  is_day  \
# 0  1695769200  2023-09-27 00:00    15.6    60.0       0
# 1  1695772800  2023-09-27 01:00    15.3    59.5       0
# 2  1695776400  2023-09-27 02:00    15.2    59.4       0
# 3  1695780000  2023-09-27 03:00    15.2    59.4       0
# 4  1695783600  2023-09-27 04:00    15.3    59.5       0
#
#                                            condition  wind_mph  wind_kph  \
# 0  {'text': 'Partly cloudy', 'icon': '//cdn.weath...       2.9       4.7
# 1  {'text': 'Partly cloudy', 'icon': '//cdn.weath...       3.4       5.4
# 2  {'text': 'Partly cloudy', 'icon': '//cdn.weath...       2.7       4.3
# 3  {'text': 'Partly cloudy', 'icon': '//cdn.weath...       3.1       5.0
# 4  {'text': 'Overcast', 'icon': '//cdn.weatherapi...       3.1       5.0
#
#    wind_degree wind_dir  ...  dewpoint_f  will_it_rain  chance_of_rain  \
# 0          205      SSW  ...        57.7             0               0
# 1          191      SSW  ...        57.4             0               0
# 2          184        S  ...        56.9             0               0
# 3          159      SSE  ...        56.4             0               0
# 4          178        S  ...        56.2             0               0
#
#    will_it_snow  chance_of_snow  vis_km  vis_miles  gust_mph  gust_kph   uv
# 0             0               0    10.0        6.0       4.5       7.3  1.0
# 1             0               0    10.0        6.0       5.4       8.7  1.0
# 2             0               0    10.0        6.0       4.3       7.0  1.0
# 3             0               0    10.0        6.0       5.1       8.2  1.0
# 4             0               0    10.0        6.0       5.1       8.1  1.0
#
# [5 rows x 33 columns]

# %% [markdown]
# Сохраним DataFrame из предыдущей задачи в файл `result.csv`. В качестве названия столбца-индекса используем `index`.

# %%
df_3.to_csv('result.csv', index_label='index')

# %% [markdown]
# Загрузим содержимое SQL-таблицы `ratings` в DataFrame. Выведем первые пять строк DataFrame на экран.

# %%
import sqlalchemy
import psycopg2

connection = 'postgresql+psycopg2://readonly:6hajV34RTQfmxhS@dsstudents.skillbox.ru:5432/db_ds_students'

engine = sqlalchemy.create_engine(connection)
connect = engine.connect()

inspector = sqlalchemy.inspect(engine)
inspector.get_table_names()

df_5 = pd.read_sql('select * from ratings', connect)
df_5.head()
# Out:
#    userid  movieid  rating   timestamp
# 0    5953     1641     3.0  1432706281
# 1    5953     1644     3.0  1432706288
# 2    5953     1645     2.0  1432706317
# 3    5953     1653     5.0  1432706333
# 4    5953     1655     4.0  1432706275

# %% [markdown]
# Сохраним первые 10 000 записей датафрейма из предыдущей задачи в файл `result2.xlsx`, при сохранении зададим листу имя `MySheet`.

# %%
df_6 = df_5.head(10000)
df_6.to_excel('result2.xlsx', sheet_name='MySheet')

# %% [markdown]
# Определим количество документов в коллекции `users` в MongoDB. Если количество документов < 1 000, то в следующей ячейке загрузим всё содержимое этой коллекции в список и выведем нулевой элемент этого списка на экран.

# %%
import pymongo

conn = 'mongodb://students:X63673t47Gl03Sq@dsstudents.skillbox.ru:27017/?authSource=movies'
connect = pymongo.MongoClient(conn)

# %%
db_7 = connect['movies']
db_7.list_collection_names()
# Out:
# ['tags', 'users']

# %%
users = db_7['users']

count = users.find()
counter = 0

for i_count in count:
    counter += 1
    
print('Количество документов в коллекции users -', counter)
# Out:
# Количество документов в коллекции users - 100

# %%
if counter < 1000:
    list_7 = list(users.find())
    
list_7[0]
# Out:
# {'_id': ObjectId('5cc69095067496679c74f7a4'),
#  'user_id': 'ed5da480-57a2-489c-8e68-512155ab9892',
#  'first_name': 'Жанна',
#  'last_name': 'Петрова',
#  'mail': 'zhanna_03816@gmail.com',
#  'age': 20.0}

# %% [markdown]
# Преобразуем список всех документов коллекции `users` из предыдущей задачи в pandas DataFrame и сохраним его содержимое в файл `result3.xlsx`.

# %%
df_8 = pd.DataFrame(list_7)
df_8.to_excel('result3.xlsx')

# %% [markdown]
# Используя данные SQL-таблицы `ratings`, для каждого пользователя (столбец `userid`) определим средний рейтинг, который этот пользователь поставил фильмам. Результат выведем на экран.
#
# Группировку проведем двумя способами: с помощью `GROUP BY` в строке запроса к БД и с использованием метода `groupby` в pandas.

# %%
result_1 = df_5.groupby('userid')['rating'].mean().reset_index()
result_1
# Out:
#       userid    rating
# 0          1  4.277778
# 1          2  3.318182
# 2          3  3.100000
# 3          4  3.500000
# 4          5  4.269231
# ...      ...       ...
# 7951    7952  3.390244
# 7952    7953  3.567568
# 7953    7954  3.750000
# 7954    7955  4.150000
# 7955    7956  3.290640
#
# [7956 rows x 2 columns]

# %%
conn = 'postgresql+psycopg2://readonly:6hajV34RTQfmxhS@dsstudents.skillbox.ru:5432/db_ds_students'

engine = sqlalchemy.create_engine(conn)
connect = engine.connect()

result_2 = pd.read_sql('select userid, avg(rating) from ratings group by userid', connect).sort_values('userid')
result_2
# Out:
#       userid       avg
# 5840       1  4.277778
# 4130       2  3.318182
# 7138       3  3.100000
# 525        4  3.500000
# 282        5  4.269231
# ...      ...       ...
# 1906    7952  3.390244
# 3728    7953  3.567568
# 6399    7954  3.750000
# 6973    7955  4.150000
# 2274    7956  3.290640
#
# [7956 rows x 2 columns]

# %% [markdown]
# Объединим таблицы `ratings` и `keywords` по столбцам `movieid` (используем левое объединение). Объединение проведём двумя способами: с помощью `LEFT JOIN` в строке запроса к БД и с использованием метода `merge` в pandas. Результат объединения загрузим в DataFrame и сохраним в файл `result4.csv`.
#
# При объединении возможно дублирование столбцов. В результирующем датафрейме не должно быть таких дублированных столбцов.

# %%
conn = 'postgresql+psycopg2://readonly:6hajV34RTQfmxhS@dsstudents.skillbox.ru:5432/db_ds_students'

engine = sqlalchemy.create_engine(connection)
connect = engine.connect()

res_1 = pd.read_sql('select * from keywords', connect)

res_1 = df_5.merge(res_1, how='left', on='movieid')

main_res = res_1.drop_duplicates()
main_res
# Out:
#          userid  movieid  rating   timestamp  \
# 0          5953     1641     3.0  1432706281
# 2          5953     1644     3.0  1432706288
# 4          5953     1645     2.0  1432706317
# 6          5953     1653     5.0  1432706333
# 8          5953     1655     4.0  1432706275
# ...         ...      ...     ...         ...
# 1118281    5953     1597     5.0  1432706312
# 1118283    5953     1603     5.0  1432706302
# 1118284    5953     1610     4.0  1432706328
# 1118286    5953     1625     4.0  1432706275
# 1118287    5953     1639     4.0  1432706322
#
#                                                       tags
# 0        [{'id': 843, 'name': 'cataclysm'}, {'id': 3800...
# 2                   [{'id': 7172, 'name': 'buried alive'}]
# 4        [{'id': 529, 'name': 'ku klux klan'}, {'id': 5...
# 6        [{'id': 983, 'name': 'brazilian'}, {'id': 2020...
# 8        [{'id': 456, 'name': 'mother'}, {'id': 1939, '...
# ...                                                    ...
# 1118281  [{'id': 591, 'name': 'cia'}, {'id': 822, 'name...
# 1118283                                                NaN
# 1118284  [{'id': 212, 'name': 'london england'}, {'id':...
# 1118286                                                NaN
# 1118287  [{'id': 1422, 'name': 'boat'}, {'id': 2799, 'n...
#
# [777776 rows x 5 columns]

# %%
main_res.to_csv('result4.csv', index_label='index')

# %%
res_2 = pd.read_sql('SELECT * FROM keywords LEFT JOIN ratings ON keywords.movieid = ratings.movieid', connect)

result = res_2.drop_duplicates()
result
# Out:
#          movieid                                               tags  userid  \
# 0           1644             [{'id': 7172, 'name': 'buried alive'}]  5953.0
# 2           1687  [{'id': 1612, 'name': 'spacecraft'}, {'id': 28...  5953.0
# 4           1732  [{'id': 1930, 'name': 'kidnapping'}, {'id': 41...  5953.0
# 6           1917  [{'id': 428, 'name': 'nurse'}, {'id': 2619, 'n...  5953.0
# 8           1918  [{'id': 549, 'name': 'prostitute'}, {'id': 559...  5953.0
# ...          ...                                                ...     ...
# 1445054    50461                                                 []     NaN
# 1445056    37404  [{'id': 1701, 'name': 'hero'}, {'id': 2035, 'n...     NaN
# 1445058    84104  [{'id': 8873, 'name': 'yeti'}, {'id': 12105, '...     NaN
# 1445060    49009  [{'id': 10685, 'name': 'escape'}, {'id': 14636...     NaN
# 1445062   122515  [{'id': 10051, 'name': 'heist'}, {'id': 221945...     NaN
#
#          movieid  rating     timestamp
# 0         1644.0     3.0  1.432706e+09
# 2         1687.0     4.0  1.432706e+09
# 4         1732.0     4.0  1.432706e+09
# 6         1917.0     4.0  1.432706e+09
# 8         1918.0     4.0  1.432706e+09
# ...          ...     ...           ...
# 1445054      NaN     NaN           NaN
# 1445056      NaN     NaN           NaN
# 1445058      NaN     NaN           NaN
# 1445060      NaN     NaN           NaN
# 1445062      NaN     NaN           NaN
#
# [381071 rows x 6 columns]

# %%
# второй способ (чтобы таблицы были одинаковыми)

df_ratings = pd.read_sql("select * from ratings", connect)
df_keywords = pd.read_sql("select * from keywords", connect)

main_df = df_ratings.merge(df_keywords, how='left', on='movieid').drop_duplicates()
main_df
# Out:
#          userid  movieid  rating   timestamp  \
# 0          5953     1641     3.0  1432706281
# 2          5953     1644     3.0  1432706288
# 4          5953     1645     2.0  1432706317
# 6          5953     1653     5.0  1432706333
# 8          5953     1655     4.0  1432706275
# ...         ...      ...     ...         ...
# 1118281    5953     1597     5.0  1432706312
# 1118283    5953     1603     5.0  1432706302
# 1118284    5953     1610     4.0  1432706328
# 1118286    5953     1625     4.0  1432706275
# 1118287    5953     1639     4.0  1432706322
#
#                                                       tags
# 0        [{'id': 843, 'name': 'cataclysm'}, {'id': 3800...
# 2                   [{'id': 7172, 'name': 'buried alive'}]
# 4        [{'id': 529, 'name': 'ku klux klan'}, {'id': 5...
# 6        [{'id': 983, 'name': 'brazilian'}, {'id': 2020...
# 8        [{'id': 456, 'name': 'mother'}, {'id': 1939, '...
# ...                                                    ...
# 1118281  [{'id': 591, 'name': 'cia'}, {'id': 822, 'name...
# 1118283                                                NaN
# 1118284  [{'id': 212, 'name': 'london england'}, {'id':...
# 1118286                                                NaN
# 1118287  [{'id': 1422, 'name': 'boat'}, {'id': 2799, 'n...
#
# [777776 rows x 5 columns]

# %%
main_df_2 = pd.read_sql('SELECT userid, ratings.movieid, rating, timestamp, tags FROM ratings LEFT JOIN keywords on ratings.movieid = keywords.movieid', connect).drop_duplicates()
main_df_2
# Out:
#          userid  movieid  rating   timestamp  \
# 0          5953     1644     3.0  1432706288
# 2          5953     1687     4.0  1432706273
# 4          5953     1704     4.0  1432706308
# 5          5953     1732     4.0  1432706332
# 7          5953     1784     3.0  1432706311
# ...         ...      ...     ...         ...
# 2125870    5953     1127     5.0  1432706315
# 2125872    5953     1213     4.0  1432706322
# 2125874    5953     1431     3.0  1432706308
# 2125875    5953     1466     5.0  1432706255
# 2125876    5953     1544     3.0  1432706297
#
#                                                       tags
# 0                   [{'id': 7172, 'name': 'buried alive'}]
# 2        [{'id': 1612, 'name': 'spacecraft'}, {'id': 28...
# 4                                                     None
# 5        [{'id': 1930, 'name': 'kidnapping'}, {'id': 41...
# 7                                                     None
# ...                                                    ...
# 2125870  [{'id': 293, 'name': 'female nudity'}, {'id': ...
# 2125872  [{'id': 110, 'name': 'venice'}, {'id': 131, 'n...
# 2125874                                               None
# 2125875                                               None
# 2125876  [{'id': 212, 'name': 'london england'}, {'id':...
#
# [777776 rows x 5 columns]

# %% [markdown]
# Используя объединенную таблицу, найдем все идентификаторы фильмов с тегом `africa` (но не `south africa` или любые другие). Список тегов в формате JSON записан в столбце `tags`.

# %%
df_11 = main_df[main_df['tags'].str.contains("'africa'", na=False)]
df_11
# Out:
#          userid  movieid  rating   timestamp  \
# 1697       5957     1672     5.0  1181077016
# 3213       5974    25874     2.5  1299345627
# 5183       5985      494     2.0   876014379
# 7371       6004      494     3.0  1046338105
# 7796       6004     2989     3.0  1046337964
# ...         ...      ...     ...         ...
# 1114618    5924      494     2.0   855412041
# 1114950    5928      494     3.0   844871089
# 1116853    5939      494     4.0   864327907
# 1117583    5949      494     4.0   833383110
# 1117849    5951      494     5.0   851629732
#
#                                                       tags
# 1697     [{'id': 90, 'name': 'paris'}, {'id': 378, 'nam...
# 3213     [{'id': 409, 'name': 'africa'}, {'id': 2043, '...
# 5183     [{'id': 90, 'name': 'paris'}, {'id': 409, 'nam...
# 7371     [{'id': 90, 'name': 'paris'}, {'id': 409, 'nam...
# 7796     [{'id': 409, 'name': 'africa'}, {'id': 2043, '...
# ...                                                    ...
# 1114618  [{'id': 90, 'name': 'paris'}, {'id': 409, 'nam...
# 1114950  [{'id': 90, 'name': 'paris'}, {'id': 409, 'nam...
# 1116853  [{'id': 90, 'name': 'paris'}, {'id': 409, 'nam...
# 1117583  [{'id': 90, 'name': 'paris'}, {'id': 409, 'nam...
# 1117849  [{'id': 90, 'name': 'paris'}, {'id': 409, 'nam...
#
# [779 rows x 5 columns]
